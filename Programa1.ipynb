# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoHdez6/PROBAYESTAD/blob/main/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
# ## Unidad: 1
# Practica: 0 Introduccion a Python
# Grupo: 2Y
# Alumno: Gustavo Edgar Hernández Núñez
# Docente: Dr. José Gabriel Rodríguez Rivas
#
# ![image.png](data:image/png;base64,...)

# %%
for i in range(10):
  print(i)
  print("Dentro del for")
  print("Fuera del for")
# Out:
# 0
# Dentro del for
# Fuera del for
# 1
# Dentro del for
# Fuera del for
# 2
# Dentro del for
# Fuera del for
# 3
# Dentro del for
# Fuera del for
# 4
# Dentro del for
# Fuera del for
# 5
# Dentro del for
# Fuera del for
# 6
# Dentro del for
# Fuera del for
# 7
# Dentro del for
# Fuera del for
# 8
# Dentro del for
# Fuera del for
# 9
# Dentro del for
# Fuera del for

# %%
# ESTE ES UN COMENTARIO
x = "Hola Hola"
print(x)
# Out:
# Hola Hola

# %%
x = 10
print(x)
# Out:
# 10

# %%
print( type(x))
# Out:
# <class 'int'>

# %%
a = 20
b= 15
if a < b:
  print(a,"es menor que",b)
else:
  print(b,"es menor que",a)
  print("Fuera del if")
# Out:
# 15 es menor que 20
# Fuera del if
